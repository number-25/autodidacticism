# %% [markdown]
# # Problem Set Week 1 MCB112
# The case of the dead sand mouse

# %% [markdown]
# ## The Experiment
# Moriarty's methods section says that he instantly kills a sand mouse at time t=0. At t=0, 12, 24, 48, and 96 hours, he dissects out the prefrontal cortex, prepared poly-A+ mRNA, and does RNA-seq. An example of the results is shown in Figure 1 from Moriarty et al.: arugula goes down after death as you might expect from being dead... but OSTC comes up at 24hrs then goes down, PRIM2 peaks at 48h, and kiwi is still coming up at 96h after death:
#
# In his discussion, Moriarty says that these data provide evidence for an ancient program of cortical gene expression that causes the sand mouse's life to flash before its eyes (very, very slowly).
#
# Well, maybe. But you suspect an artifact of some kind. You decide to look into the result. After carefully reading the paper, it looks like there aren't any obvious problems with the RNA-seq experiment itself. Each data point is an average over several dead sand mice, and the variation seems small, so it's not that this is just experimental noise. The dissections seem carefully done, so it's not that he mistakenly collected anatomically different chunks of brain (which could easily give gene expression differences). He also did some controls to make sure that the relative proportions of different cell types in the dissected tissue hadn't changed much (a common problem in differential RNA-seq analysis of tissues composed of mixtures of cell types: you measure a population average, so if cell type composition changes, it can look like gene expression changes.) Everything suggests to you that the expression level (TPM) calls are reproducible and robust, so if there's a problem, it's in his interpretation of the expression levels.

# %% [markdown]
# ## The Data
# The expression data for the paper are available in his Supplementary Data Table 1: Moriarty_SuppTable1.
#
# It happens that you've also just been reading another paper from Irene Adler's lab that seems relevant. Adler et al. systematically measured mRNA synthesis rates (in mRNA/hr) and mRNA halflife (in hr), also in the prefrontal cortex, for every gene in the sand mouse. Those data are available in their Supplementary Data Table 2: Adler_SuppTable2.
#
# Download both data files.

# %% [markdown]
# ### 1. Check that the gene names match
# Write a script to compare the gene names in the two data files. Output the names that appear in Moriarty_SuppTable1 but not Adler_SuppTable2, if any. Use plain Python for this pset. Don't use any additional data wrangling packages, if you already happen to know it. One of the points of the pset is to be able to ingest crappily-formatted data files, by writing your own parsing code.

# %%
sup_one = readlines(open("Sup_1.txt"))
# Out:
# WARNING: Force throwing a SIGINT

# %%
sup_two = readlines(open("Sup_2.txt"))
# Out:
# 20032-element Vector{String}:
#  "gene_name     synth_rate halflife"
#  "CYB5R3               3.2     19.9"
#  "MMAA                 1.1      9.5"
#  "SLC24A1              0.8     14.8"
#  "OR10D3              12.6     14.0"
#  "IFITM5               2.5     20.3"
#  "CDC5L                0.7      8.3"
#  "DPYSL2               1.4     26.5"
#  "ERCC6                1.0     11.3"
#  "SYCE2                1.7     23.0"
#  "CHST7                2.1      5.5"
#  "PFDN2                6.6     17.2"
#  "PHKB                 0.3     17.5"
#  ⋮
#  "FGF23                6.6      8.8"
#  "SPINK6               1.9      9.3"
#  "RUNX1T1              1.4     14.8"
#  "GABRB1               3.4     23.6"
#  "GJC1                 4.4     23.1"
#  "TFRC                 2.4     99.5"
#  "STK24                1.7      9.4"
#  "MTUS1                4.7     21.0"
#  "TRIM42               2.2     17.2"
#  "IRF7                10.4     10.2"
#  "HSPE1                2.8     17.0"
#  "EYS                  1.8     14.1"

# %%
split(sup_one[2], " ")[1]
# Out:
# "anise"

# %%
sup_one[2]
# Out:
# "anise              5.4    5.2    4.8    3.1    0.6 "

# %%
sup_one_genes = []
for line in sup_one[2:end]
    split_line = split(line)
    gene_name = split_line[1]
    push!(sup_one_genes, gene_name)
end

# %%
in(sup_one[1], sup_one)
# Out:
# true

# %%
sup_two_genes = []
for line in sup_two[2:end]
    split_line = split(line)
    gene_name = split_line[1]
    push!(sup_two_genes, gene_name)
end

# %%
common_genes = intersect(sup_one_genes, sup_two_genes)
# Out:
# 20003-element Vector{Any}:
#  "anise"
#  "apricot"
#  "artichoke"
#  "arugula"
#  "asparagus"
#  "avocado"
#  "banana"
#  "basil"
#  "beet"
#  "blackberry"
#  "blueberry"
#  "broccoli"
#  "butternut"
#  ⋮
#  "AL592183.1"
#  "AC007325.1"
#  "AC007325.4"
#  "AC007325.2"
#  "BX072566.1"
#  "AL354822.1"
#  "AC023491.2"
#  "AC004556.1"
#  "AC233755.2"
#  "AC233755.1"
#  "AC240274.1"
#  "AC213203.1"

# %%
length(sup_one_genes)
# Out:
# 20031

# %%
length(sup_two_genes)
# Out:
# 20031

# %%
length(common_genes)
# Out:
# 20003

# %% [markdown]
# Is there a difference?
# Yes, there are 28 genes that are not shared between the two supplementary tables

# %%
corrupt_genes = setdiff(sup_one_genes, sup_two_genes)
# Out:
# 26-element Vector{Any}:
#  "15-Sep"
#  "2-Mar"
#  "1-Mar"
#  "10-Sep"
#  "7-Mar"
#  "4-Mar"
#  "2-Sep"
#  "11-Sep"
#  "6-Mar"
#  "11-Mar"
#  "3-Mar"
#  "8-Sep"
#  "7-Sep"
#  "14-Sep"
#  "6-Sep"
#  "1-Dec"
#  "8-Mar"
#  "5-Mar"
#  "9-Mar"
#  "12-Sep"
#  "1-Sep"
#  "4-Sep"
#  "10-Mar"
#  "9-Sep"
#  "5-Sep"
#  "3-Sep"

# %% [markdown]
# All of these different genes are dates - likely due to xlsx formating error. Omit them from the analysis

# %% [markdown]
# #### Create new supplementary files with these names ommitted

# %%
new_sup_one = Vector()
@time for line in sup_one
        gene = split(line, " ")[1]
            if gene ∉ corrupt_genes
            push!(new_sup_one, line)        
            end
    end
# Out:
#   0.120025 seconds (643.74 k allocations: 42.403 MiB, 11.51% gc time)

# %%
length(new_sup_one)
# Out:
# 20004

# %% [markdown]
# The incorrectly formatted genes are from supplementary file one.

# %%
new_sup_two = Vector()
@time for line in sup_two
        gene = split(line, " ")[1]
            if gene ∉ corrupt_genes
            push!(new_sup_two, line)        
            end
    end
# Out:
#   0.065647 seconds (640.52 k allocations: 42.186 MiB, 10.92% gc time)

# %%
length(new_sup_two)
# Out:
# 20032

# %% [markdown]
# ### 2. Explore the data
# Output the five genes with the highest mRNA synthesis rate
#
# I am thinking that I will create a dict which maps the gene name to the synthesis rate, and then I can easily sort the synthesis values.

# %% [markdown]
# Because the supplementary file is inconsistently formatted, with varying amounts of whitespace delimiters between the variable values, we should tidy it up and make it into a consistent comma delimited array.

# %%
# We don't want to print white spaces, but remove them! 
final_sup_two = Vector{String}()
for line in new_sup_two[2:end]
    new_line = Vector()
    for char in eachindex(line) # each eachindex() function to list out iterate over indices
        if line[char] != ' ' # if we encounter a non-space character, send it to the array
            new_line = push!(new_line, line[char]) 
        elseif line[char] == ' ' && line[char-1] != ' ' # If we encounter a space, but the previous index is not a space, send it to array
            new_line = push!(new_line, ',')
        end 
    end 
    push!(final_sup_two, join(new_line))
end

# %%
sup_two_dict = Dict{AbstractString, Float64}() # Has to be this specific Type fields as otherwise sorting doesn't work as intended
for gene in final_sup_two[2:end]
    split_line = split(gene, ",")
    sup_two_dict[split_line[1]] = parse(Float64, split_line[2])
end

# %%
sup_two_dict
# Out:
# Dict{AbstractString, Float64} with 20030 entries:
#   "MMP11"     => 3.7
#   "TMOD4"     => 14.1
#   "ETV4"      => 0.8
#   "DNASE2"    => 0.8
#   "PRH1"      => 11.1
#   "MOB4"      => 4.2
#   "KAT2A"     => 3.0
#   "GCNT3"     => 1.0
#   "SREBF2"    => 5.9
#   "APOC2"     => 2.6
#   "CDC40"     => 2.0
#   "HLA-B"     => 1.9
#   "FAXC"      => 0.6
#   "NAGS"      => 4.7
#   "CYP2C19"   => 6.6
#   "TMEM74B"   => 5.2
#   "CNN3"      => 6.3
#   "HOXD4"     => 1.5
#   "TNFRSF11B" => 4.4
#   "AMZ2"      => 7.3
#   "ACER2"     => 6.3
#   "TPP2"      => 1.1
#   "THBS4"     => 7.0
#   "MED9"      => 4.1
#   "NBPF4"     => 3.3
#   ⋮           => ⋮

# %%
sorted_sup_two_rates = sort(collect(sup_two_dict), by = x -> x[2], rev = true) ; first(sorted_sup_two_rates, 5)
# Out:
# 5-element Vector{Pair{AbstractString, Float64}}:
#  "CCDC169-SOHLH2" => 114.7
#          "DDX60L" => 80.1
#           "LRRK1" => 75.3
#        "SLC25A45" => 70.1
#           "FARP1" => 68.2

# %% [markdown]
# #### Answer
# The five genes with the highest mRNA synthesis rate are
# 1. CCDC169-SOHLH2 => 114.7
# 2. DDX60L => 80.1
# 3. LRRK1 => 75.3
# 4. SLC25A45 => 70.1
# 5. FARP1 => 68.2

# %% [markdown]
# Output the five genes with the longest mRNA halflife

# %%
sup_two_dict_halflife = Dict{AbstractString, Float64}() # Has to be this specific Type fields as otherwise sorting doesn't work as intended
for gene in final_sup_two[2:end]
    split_line = split(gene, ",")
    sup_two_dict_halflife[split_line[1]] = parse(Float64, split_line[3])
end

# %%
sup_two_dict_halflife
# Out:
# Dict{AbstractString, Float64} with 20030 entries:
#   "MMP11"     => 18.6
#   "TMOD4"     => 6.5
#   "ETV4"      => 9.2
#   "DNASE2"    => 18.7
#   "PRH1"      => 12.6
#   "MOB4"      => 11.8
#   "KAT2A"     => 13.7
#   "GCNT3"     => 16.2
#   "SREBF2"    => 22.6
#   "APOC2"     => 20.9
#   "CDC40"     => 16.5
#   "HLA-B"     => 18.9
#   "FAXC"      => 8.7
#   "NAGS"      => 10.2
#   "CYP2C19"   => 6.3
#   "TMEM74B"   => 8.2
#   "CNN3"      => 16.5
#   "HOXD4"     => 16.6
#   "TNFRSF11B" => 17.6
#   "AMZ2"      => 13.7
#   "ACER2"     => 16.8
#   "TPP2"      => 13.0
#   "THBS4"     => 6.6
#   "MED9"      => 21.0
#   "NBPF4"     => 18.0
#   ⋮           => ⋮

# %%
sorted_sup_two_halflife = sort(collect(sup_two_dict_halflife), by = x -> x[2], rev = true) ; first(sorted_sup_two_halflife, 5)
# Out:
# 5-element Vector{Pair{AbstractString, Float64}}:
#    "TFRC" => 99.5
#  "SPINK8" => 71.8
#   "DIRC1" => 67.3
#   "PLA1A" => 61.5
#  "SAMSN1" => 58.1

# %% [markdown]
# #### Answer
# The tope five genes with the longest half-life are
# 1. TFRC => 99.5
# 2. SPINK8 => 71.8
# 3. DIRC1 => 67.3
# 4. PLA1A => 61.5
# 5. SAMSN1 => 58.1

# %% [markdown]
# #### 3. Figure out what happened
# Write a script that merges the two data files, line by line, merging them on gene name. That is, for each line in file 1 for gene X, find the corresponding line for gene X in file 2; we're going to write a single output file with one line per gene. The genes are in different orders in the files, so this merge isn't entirely trivial. For any gene name X that isn't found in both files (cough cough Excel corruption cough cough) just skip it. For each gene name that is found in both files, output one whitespace-delimited, column-justified data line consisting of 7 fields per line:

# %% [markdown]
# Create a final, cleanly formatted supplementary file 2

# %%
final_sup_one = Vector{String}()
for line in new_sup_one[2:end]
    new_line = Vector()
    for char in eachindex(line) # each eachindex() function to list out iterate over indices
        if line[char] != ' ' # if we encounter a non-space character, send it to the array
            new_line = push!(new_line, line[char]) 
        elseif line[char] == ' ' && line[char-1] != ' ' # If we encounter a space, but the previous index is not a space, send it to array
            new_line = push!(new_line, ',')
        end 
    end 
    push!(final_sup_one, join(new_line))
end

# %%
final_sup_one
# Out:
# 20003-element Vector{String}:
#  "anise,5.4,5.2,4.8,3.1,0.6,"
#  "apricot,13.4,14.6,12.4,8.6,1.9,"
#  "artichoke,4.2,1.5,0.5,0.0,0.0,"
#  "arugula,66.9,23.9,7.0,0.5,0.0,"
#  "asparagus,55.6,78.1,100.9,135.8,115.0,"
#  "avocado,27.0,14.3,6.2,1.1,0.0,"
#  "banana,101.3,132.2,126.7,130.7,68.7,"
#  "basil,3.1,1.1,0.4,0.0,0.0,"
#  "beet,3.8,1.1,0.3,0.0,0.0,"
#  "blackberry,23.9,15.6,9.1,2.5,0.1,"
#  "blueberry,7.3,4.5,2.0,0.4,0.0,"
#  "broccoli,16.4,14.1,11.1,5.4,0.7,"
#  "butternut,24.5,27.9,23.5,16.7,4.5,"
#  ⋮
#  "AL592183.1,33.7,45.8,52.5,62.8,53.5,"
#  "AC007325.1,77.7,51.8,27.9,6.5,0.2,"
#  "AC007325.4,34.3,34.4,38.6,30.0,12.6,"
#  "AC007325.2,7.3,7.4,6.7,4.0,1.0,"
#  "BX072566.1,26.9,29.1,26.5,25.1,9.0,"
#  "AL354822.1,49.9,53.8,62.9,57.3,37.4,"
#  "AC023491.2,156.4,173.5,174.9,116.0,42.1,"
#  "AC004556.1,68.9,59.9,51.5,26.9,4.7,"
#  "AC233755.2,56.5,49.6,37.1,18.2,2.4,"
#  "AC233755.1,1.9,1.1,0.5,0.1,0.0,"
#  "AC240274.1,10.1,10.7,9.3,4.8,0.8,"
#  "AC213203.1,31.0,37.3,37.8,35.1,18.8,"

# %%
merged_vector = Vector{String}()
for line in final_sup_one[1:1000]
    new_merged_line = Vector()
    split_line_measures = split(line, ',')[2:end]
    split_line_gene = split(line, ',')[1]
    search = findall( x -> occursin(split_line_gene, x), final_sup_two)
    @show search
        found_index = findall( x -> occursin(split_line_gene, x), final_sup_two)
        push!(new_merged_line, final_sup_two[found_index])
        push!(new_merged_line, split_line_measures)
        
        #if split_line_gene ∈ keys(sup_two_dict_halflife)
     #   push!(
    #end 
end
# Out:
# search = [434]
# search = [3933]
# search = [8465]
# search = [77]
# search = [9045]
# search = [3176]
# search = [17345]
# search = [18708]
# search = [11089]
# search = [11873]
# search = [10486]
# search = [18471]
# search = [13004]
# search = [12337]
# search = [19876]
# search = [1357]
# search = [15047]
# search = [4556]
# search = [19746]
# search = [19111]
# search = [2931]
# search = [4848]
# search = [19615]
# search = [17865]
# search = [8544]
# search = [10864]
# search = [2377]
# search = [17358]
# search = [12575]
# search = [1512]
# search = [17513]
# search = [12327]
# search = [6668]
# search = [10962]
# search = [6036]
# search = [12477]
# search = [13754]
# search = [5149]
# search = [7708]
# search = [416, 992]
# search = [416]
# search = [6718]
# search = [10441]
# search = [11550]
# search = [1436]
# search = [8075]
# search = [13153]
# search = [15268]
# search = [7275]
# search = [19305]
# search = [1032]
# search = [11965]
# search = [16001]
# search = [4687]
# search = [3944]
# search = [6724, 15764]
# search = [11822]
# search = [7705]
# search = [6065]
# search = [14561]
# search = [10232]
# search = [19920]
# search = [19630]
# search = [13820]
# search = [14719]
# search = [19812]
# search = [7256]
# search = [15178]
# search = [62, 1747, 17865, 18226]
# search = [62]
# search = [1747]
# search = [9326]
# search = [11496]
# search = [5599]
# search = [2163]
# search = [123]
# search = [14555]
# search = [11103]
# search = [13495]
# search = [8347]
# search = [6091, 11550]
# search = [7534]
# search = [19061]
# search = [16392]
# search = [9526]
# search = [13343]
# search = [7506]
# search = [3389]
# search = [6864]
# search = [18414]
# search = [15121]
# search = [10555]
# search = [17454]
# search = [9346]
# search = [13355]
# search = [4114]
# search = [15285]
# search = [15764]
# search = [13019]
# search = [10048]
# search = [3382]
# search = [19323]
# search = [15849]
# search = [18488]
# search = [8194]
# search = [1882]
# search = [3117]
# search = [17517]
# search = [5343]
# search = [13979]
# search = [9564]
# search = [13781]
# search = [10964]
# search = [3844]
# search = [2906]
# search = [18990]
# search = [14289]
# search = [2427]
# search = [4092]
# search = [18751]
# search = [13727]
# search = [15324]
# search = [14118]
# search = [15111]
# search = [2923]
# search = [18303]
# search = [5427]
# search = [5915]
# search = [13487]
# search = [7065]
# search = [17184]
# search = [19149]
# search = [13408]
# search = [1731]
# search = [4290]
# search = [13247]
# search = [16042]
# search = [9094]
# search = [8160]
# search = [14368]
# search = [3291]
# search = [14883]
# search = [7312]
# search = [18369]
# search = [3240]
# search = [15786]
# search = [11245]
# search = [9303]
# search = [8705, 11245]
# search = [863, 16610]
# search = [315, 13371]
# search = [2184]
# search = [894, 12142]
# search = [18544]
# search = [7488]
# search = [15157]
# search = [15532]
# search = [5334, 5618, 5933, 6707, 6944, 14492, 14750, 16990]
# search = [13216]
# search = [554]
# search = [2780]
# search = [10556]
# search = [17248]
# search = [13402]
# search = [17541]
# search = [4865]
# search = [1753]
# search = [15711]
# search = [18198]
# search = [12894]
# search = [13607]
# search = [13294]
# search = [18095]
# search = [8095]
# search = [14665]
# search = [6522]
# search = [700, 4499, 6969, 8945, 12492, 13181, 13213, 15829, 16490, 17460, 17769, 19035, 19232, 19905]
# search = [16262]
# search = [18296]
# search = [8928]
# search = [6374]
# search = [10847]
# search = [14402]
# search = [11131]
# search = [8282, 14146]
# search = [3834, 4532, 7829]
# search = [11143]
# search = [11576]
# search = [10152]
# search = [757]
# search = [11459]
# search = [6892]
# search = [19315, 19775]
# search = [6505]
# search = [2300]
# search = [12424]
# search = [1513]
# search = [12889]
# search = [18560]
# search = [9774]
# search = [12089]
# search = [8089]
# search = [5369]
# search = [3131]
# search = [10944, 19839]
# search = [7466, 14983, 16454, 19022]
# search = [4286]
# search = [3664]
# search = [7722]
# search = [1496]
# search = [18492]
# search = [14333]
# search = [1527, 5701, 6836]
# search = [7054]
# search = [18154]
# search = [13856]
# search = [11454]
# search = [17376]
# search = [9755]
# search = [1119]
# search = [23]
# search = [17119]
# search = [18391]
# search = [19159]
# search = [4245]
# search = [4448]
# search = [10649]
# search = [4854]
# search = [1842, 15086]
# search = [4597, 12973, 13932]
# search = [1345]
# search = [1345, 17584]
# search = [1345, 9562]
# search = [4302]
# search = [6773]
# search = [18942]
# search = [355]
# search = [17566]
# search = [1755]
# search = [3465]
# search = [7058, 11850]
# search = [17319]
# search = [7258, 8556, 9386, 14949, 15818, 19584]
# search = [9686]
# search = [1274]
# search = [18589]
# search = [2218, 7045, 8752, 12800, 13087, 13506, 13778]
# search = [11246]
# search = [9425]
# search = [2433]
# search = [1522]
# search = [17230]
# search = [7163]
# search = [12793]
# search = [1267]
# search = [6723]
# search = [3662]
# search = [2220]
# search = [18493]
# search = [14566]
# search = [13808]
# search = [16373]
# search = [7931]
# search = [12799]
# search = [13620]
# search = [10743]
# search = [5462]
# search = [8179]
# search = [18121]
# search = [958, 1286, 3219, 6189, 17668, 17812, 18121, 18875, 19635]
# search = [19635]
# search = [6983]
# search = [133, 15021, 18152, 18793, 19381]
# search = [302]
# search = [1286]
# search = [13403]
# search = [16371]
# search = [15021]
# search = [18152]
# search = [1040]
# search = [4211]
# search = [19381]
# search = [846]
# search = [11284]
# search = [17812]
# search = [10185]
# search = [14201]
# search = [3219]
# search = [958]
# search = [17668]
# search = [6189]
# search = [18793]
# search = [16563]
# search = [9952]
# search = [5376]
# search = [9852]
# search = [2859]
# search = [7181]
# search = [6178]
# search = [3010]
# search = [3876]
# search = [4308]
# search = [6776]
# search = [16647]
# search = [19387]
# search = [18228]
# search = [3751]
# search = [7681]
# search = [5228]
# search = [13323]
# search = [12236]
# search = [10256]
# search = [20014]
# search = [9903]
# search = [14905]
# search = [15274]
# search = [19266]
# search = [13728]
# search = [8371]
# search = [3602]
# search = [11990]
# search = [5407]
# search = [3296]
# search = [5922]
# search = [13288]
# search = [11770]
# search = [11970]
# search = [3050, 3727, 6529, 8143, 12554, 14866, 17073]
# search = [1016]
# search = [4178]
# search = [4304, 4511]
# search = [18407]
# search = [16474]
# search = [14797]
# search = [11030]
# search = [12827]
# search = [10427]
# search = [15950]
# search = [8731]
# search = [18459]
# search = [6218, 11463, 11651, 19960]
# search = [17663]
# search = [6297]
# search = [14478]
# search = [10975]
# search = [3999]
# search = [9473]
# search = [2913]
# search = [17683]
# search = [2552]
# search = [8359]
# search = [9373, 11592]
# search = [14792]
# search = [15569]
# search = [5277]
# search = [953, 13610]
# search = [12732]
# search = [5773, 10651]
# search = [10651]
# search = [2106, 7766, 8040, 10651]
# search = [14412]
# search = [19166]
# search = [8176]
# search = [15703]
# search = [8059]
# search = [11067]
# search = [7709]
# search = [14125]
# search = [6786]
# search = [8461]
# search = [9069]
# search = [3495]
# search = [806]
# search = [16977]
# search = [6932]
# search = [1089, 3828, 15200, 16765]
# search = [4425, 6656, 13483, 17357]
# search = [1824]
# search = [17352]
# search = [13449]
# search = [13545]
# search = [6980]
# search = [5689]
# search = [6828]
# search = [10404]
# search = [4277, 12752]
# search = [16774]
# search = [13864]
# search = [2328]
# search = [5243]
# search = [10006]
# search = [596, 4934, 6912, 7158, 8504, 11121, 13336, 14240, 16517, 16729, 18581, 19803]
# search = [1904]
# search = [13259]
# search = [2144]
# search = [438]
# search = [12629]
# search = [6473, 6930]
# search = [12454]
# search = [15329]
# search = [13735]
# search = [17900]
# search = [5969]
# search = [18530]
# search = [14065]
# search = [16084]
# search = [19947]
# search = [15307]
# search = [8223]
# search = [7238, 7317, 8264, 10699, 12207, 16370, 17703]
# search = [15035]
# search = [9881, 10397]
# search = [1175, 4771, 6415, 7115, 12172]
# search = [6778]
# search = [13477]
# search = [17981]
# search = [10373, 16433]
# search = [19829]
# search = [14579]
# search = [2353]
# search = [13752]
# search = [1555]
# search = [5660]
# search = [4968]
# search = [9651]
# search = [11975]
# search = [6871]
# search = [4728]
# search = [9777]
# search = [203]
# search = [13269]
# search = [11423]
# search = [17972]
# search = [17055]
# search = [7439, 11134, 12540]
# search = [8288]
# search = [16521]
# search = [18925]
# search = [11261]
# search = [10641]
# search = [319]
# search = [4154]
# search = [3539]
# search = [13182]
# search = [493]
# search = [10227]
# search = [10109]
# search = [5195]
# search = [6348]
# search = [14119]
# search = [3799]
# search = [6004]
# search = [7643]
# search = [17616]
# search = [11305]
# search = [17029]
# search = [11200]
# search = [4990, 9261]
# search = [12634]
# search = [2790]
# search = [5815]
# search = [6880]
# search = [3900]
# search = [16359]
# search = [1521]
# search = [10737]
# search = [1206]
# search = [16676]
# search = [7900]
# search = [9165]
# search = [3728]
# search = [6307]
# search = [17665]
# search = [889, 1209, 3349, 13505]
# search = [9549]
# search = [13048]
# search = [4636]
# search = [2925]
# search = [11723]
# search = [1792]
# search = [771]
# search = [9350]
# search = [12174]
# search = [4155]
# search = [19702]
# search = [17153]
# search = [4826, 5429, 6328, 8422, 8549, 12662, 14078, 18054, 19637]
# search = [7611]
# search = [13740]
# search = [8151]
# search = [8595]
# search = [9483]
# search = [2422]
# search = [11780]
# search = [19465]
# search = [8777]
# search = [17392]
# search = [15011]
# search = [572]
# search = [7445]
# search = [15789]
# search = [7125]
# search = [15459]
# search = [12763]
# search = [13229]
# search = [17992]
# search = [2304, 2645, 4029, 4534, 9161, 13688, 16591]
# search = [2652]
# search = [6989]
# search = [19567]
# search = [11530]
# search = [5655]
# search = [2462]
# search = [644, 4977, 6421, 6897, 11449, 13422, 14462]
# search = [9441]
# search = [15891]
# search = [923, 12368, 14266]
# search = [11010]
# search = [14927]
# search = [14626]
# search = [18551]
# search = [5041]
# search = [5743]
# search = [4885]
# search = [16100]
# search = [7884]
# search = [6780]
# search = [11726]
# search = [8800]
# search = [6767, 8249, 9988]
# search = [16688]
# search = [293]
# search = [6513]
# search = [17166]
# search = [1323]
# search = [17659]
# search = [652]
# search = [14689]
# search = [15276]
# search = [1102]
# search = [3556]
# search = [16755]
# search = [9847]
# search = [891]
# search = [677]
# search = [8468, 12140, 14624]
# search = [4261]
# search = [3119]
# search = [15768]
# search = [6095]
# search = [14598]
# search = [7943]
# search = [515]
# search = [4096]
# search = [1833]
# search = [10570, 17433]
# search = [11268]
# search = [5683, 6577]
# search = [3363]
# search = [13003]
# search = [1392, 13064, 13557]
# search = [15656]
# search = [3246]
# search = [1404, 2136, 6265, 6552, 8029, 9941, 12703, 14699, 17238, 18571]
# search = [4888]
# search = [11489]
# search = [11529]
# search = [4208]
# search = [19184]
# search = [13991]
# search = [10279]
# search = [7915]
# search = [3017]
# search = [15829]
# search = [8827]
# search = [5989]
# search = [8722]
# search = [19129]
# search = [18367]
# search = [10798]
# search = [1023]
# search = [18049]
# search = [16746]
# search = [13695]
# search = [15099]
# search = [11392]
# search = [47]
# search = [18086]
# search = [18531]
# search = [18540]
# search = [684]
# search = [8873]
# search = [3715]
# search = [17374]
# search = [2321]
# search = [2248]
# search = [13026]
# search = [1459, 12417]
# search = [5985]
# search = [19523]
# search = [18777]
# search = [11493]
# search = [8326]
# search = [4017]
# search = [18642]
# search = [1294]
# search = [6730]
# search = [1592]
# search = [11784]
# search = [6655]
# search = [13491]
# search = [7120]
# search = [2190]
# search = [8868]
# search = [2223]
# search = [2102]
# search = [18987]
# search = [4326]
# search = [9593]
# search = [8481]
# search = [7121, 12898]
# search = [11278]
# search = [17613]
# search = [3048]
# search = [19208]
# search = [16281]
# search = [13592]
# search = [6175, 8985, 17008]
# search = [3267]
# search = [10839]
# search = [17632]
# search = [9845]
# search = [586]
# search = [161]
# search = [15873]
# search = [3368, 6406]
# search = [4162]
# search = [12795]
# search = [13557]
# search = [16014]
# search = [5696]
# search = [8688]
# search = [12742]
# search = [16291]
# search = [3027]
# search = [4293, 5505, 7657]
# search = [19657]
# search = [3448, 12944, 17790, 18161]
# search = [10674]
# search = [19633]
# search = [12440]
# search = [14423]
# search = [12729]
# search = [6165, 12729]
# search = [10907]
# search = [15784]
# search = [8510]
# search = [12382]
# search = [1721]
# search = [5384]
# search = [682]
# search = [3358]
# search = [2692]
# search = [16311]
# search = [12026]
# search = [18102]
# search = [15861]
# search = [19000]
# search = [18007]
# search = [9722]
# search = [237]
# search = [12780]
# search = [18215]
# search = [9208]
# search = [11797]
# search = [3352]
# search = [4938]
# search = [1160]
# search = [5001]
# search = [15626]
# search = [18516]
# search = [6774]
# search = [11101]
# search = [146, 584, 6326, 11417, 11687, 17529]
# search = [9561]
# search = [12864]
# search = [17465]
# search = [11952]
# search = [14080]
# search = [14657]
# search = [14655, 15587]
# search = [6526, 12143]
# search = [14265]
# search = [3179, 10002]
# search = [16237]
# search = [8387]
# search = [3802]
# search = [3491]
# search = [14427]
# search = [10636]
# search = [17832]
# search = [15145]
# search = [11401]
# search = [7603]
# search = [10783]
# search = [18438]
# search = [18449]
# search = [11339]
# search = [18640]
# search = [15376]
# search = [17109]
# search = [2030]
# search = [14933]
# search = [4976]
# search = [5094]
# search = [19828]
# search = [12823]
# search = [15070]
# search = [17295]
# search = [9247]
# search = [13746]
# search = [14968]
# search = [2113, 3003, 8663, 9639, 9729]
# search = [18061]
# search = [138]
# search = [1320]
# search = [6520]
# search = [2080]
# search = [16607]
# search = [5145]
# search = [5171]
# search = [9048]
# search = [15692]
# search = [1645, 3529, 3687, 5140, 5791, 7076, 7461, 8760, 13696, 19885]
# search = [6117]
# search = [10706]
# search = [5378, 10950, 13409, 15326, 16289]
# search = [12690]
# search = [3130]
# search = [2646, 2787, 3150, 9053, 9775, 10778, 12325, 12398, 12720, 13907, 14987]
# search = [1498]
# search = [5469]
# search = [4031, 15483]
# search = [2307, 16797]
# search = [8494]
# search = [10256, 11665]
# search = [11928]
# search = [2164, 16175]
# search = [14952]
# search = [3818]
# search = [12128]
# search = [551]
# search = [4426]
# search = [10124]
# search = [15414]
# search = [13180]
# search = [8665]
# search = [9815]
# search = [4587]
# search = [3034]
# search = [17261]
# search = [11000]
# search = [19040]
# search = [12515]
# search = [5189]
# search = [11251]
# search = [10697]
# search = [13822]
# search = [19551]
# search = [9725]
# search = [1967, 4939]
# search = [12913]
# search = [5774]
# search = [6186]
# search = [8146]
# search = [461, 13233]
# search = [8178]
# search = [6302]
# search = [2950, 6495, 10304, 10383, 12717, 15079, 19193]
# search = [5048]
# search = [17522, 18352]
# search = [3777]
# search = [14663]
# search = [6444]
# search = [12017]
# search = [7295]
# search = [19367]
# search = [9803]
# search = [13178]
# search = [8222, 10365, 10565, 15183]
# search = [19247]
# search = [4171]
# search = [19696]
# search = [2325]
# search = [11967, 16327]
# search = [14540]
# search = [662]
# search = [2333]
# search = [7745, 12885]
# search = [2556]
# search = [9172, 16601]
# search = [12668]
# search = [16343]
# search = [6816]
# search = [3688, 11633]
# search = [6130, 8938]
# search = [12970]
# search = [14472]
# search = [2860, 4562, 5965, 6972, 7157, 7312, 9530, 9935, 10544, 12017, 13544, 17176, 19224]
# search = [1943]
# search = [8874]
# search = [8555]
# search = [594]
# search = [911]
# search = [5830, 18133]
# search = [2159]
# search = [5698]
# search = [14480]
# search = [8754]
# search = [7477]
# search = [12658]
# search = [7216]
# search = [11409]
# search = [1020, 1772]
# search = [1020]
# search = [1020, 17209]
# search = [1322]
# search = [15598]
# search = [9959]
# search = [11389]
# search = [19358]
# search = [8100]
# search = [4840]
# search = [15492]
# search = [3419]
# search = [16189]
# search = [14179]
# search = [3904, 4989, 9019, 12006, 14242, 16784, 18564]
# search = [5885, 10247, 17064, 18453, 18827]
# search = [485]
# search = [16398]
# search = [13314]
# search = [1309]
# search = [10095, 16199, 17771]
# search = [12036]
# search = [5045]
# search = [1021]
# search = [8370]
# search = [9733]
# search = [16171]
# search = [11849]
# search = [6788]
# search = [2502]
# search = [82, 180, 253, 532, 752, 866, 1217, 1561, 1713, 1821, 2571, 2636, 3058, 3572, 4553, 5293, 5437, 5784, 6242, 6753, 7274, 7498, 8428, 10806, 10824, 11156, 11659, 12063, 13383, 13480, 14890, 15469, 16020, 16565, 16586, 16788, 17007, 17385, 18148, 18306, 18579, 19009, 19222, 19585, 19717, 19892]
# search = [18765]
# search = [2654]
# search = [6464]
# search = [12189]
# search = [9581]
# search = [10066]
# search = [16491]
# search = [11035]
# search = [2979]
# search = [18682]
# search = [10013]
# search = [4653]
# search = [15732]
# search = [2489, 6350, 12101, 19391]
# search = [17924]
# search = [14671, 15835]
# search = [961, 14671, 15835]
# search = [5934]
# search = [18566]
# search = [13887]
# search = [15392]
# search = [6798]
# search = [9277]
# search = [17777]
# search = [2155]
# search = [7021]
# search = [8399]
# search = [7096]
# search = [1973]
# search = [15112]
# search = [17597]
# search = [15065]
# search = [4630]
# search = [3796, 10192]
# search = [1975, 3072, 4798, 10250, 10350, 11411, 11739, 12001, 12613]
# search = [13045]
# search = [17103]
# search = [6133]
# search = [3455]
# search = [12198]
# search = [11336, 11574]
# search = [17019]
# search = [6194]
# search = [13171]
# search = [5884]
# search = [3129, 16479]
# search = [16479]
# search = [16479, 19558]
# search = [1352]
# search = [5044]
# search = [10722, 16158]
# search = [3081]
# search = [14098]
# search = [8617]
# search = [17394]
# search = [289]
# search = [17363]
# search = [16038]
# search = [3096]
# search = [5848]
# search = [8757]
# search = [3624, 13334]
# search = [12980]
# search = [5283]
# search = [4055]
# search = [5816]
# search = [12830]
# search = [6115]
# search = [15259]
# search = [5651, 10249]
# search = [18775]
# search = [11548, 18775]
# search = [10932]
# search = [4227]
# search = [17434]
# search = [1582]
# search = [10793]
# search = [3526]
# search = [172, 5633, 5903, 6821]
# search = [2607]
# search = [3077]
# search = [15458]
# search = [1189]
# search = [16462]
# search = [10511]
# search = [13224]
# search = [16453]
# search = [3174]
# search = [1894]
# search = [13498]
# search = [5107]
# search = [6734]
# search = [4647]
# search = [15072]
# search = [12385]
# search = [19967]
# search = [18104]
# search = [12495]
# search = [19867]
# search = [2569]
# search = [4418]
# search = [10723]
# search = [14779]
# search = [15943]
# search = [2171]
# search = [7642]
# search = [24, 3938, 17662]
# search = [717]
# search = [601]
# search = [81]
# search = [8505]
# search = [16335]
# search = [5885]
# search = [11256]
# search = [11498]
# search = [4399]
# search = [14111]
# search = [14147]
# search = [7517]
# search = [8919, 11588]
# search = [462, 2388, 4590, 5279, 5706, 6823, 7846, 16673, 17664, 19094, 19906]
# search = [13692, 16341]
# search = [17335]
# search = [3929]
# search = [6166]
# search = [3498, 12707]
# search = [13256]
# search = [17518]
# search = [9145]
# search = [960]
# search = [11981, 13744]
# search = [11877, 13437]
# search = [4423, 7668, 10629, 10707, 11086, 13710, 15061, 17961, 18192]
# search = [4811]
# search = [9949]
# search = [6977]
# search = [2501, 5039, 5412, 8613, 9263, 12483, 12679, 13829, 15833, 19080, 19136]
# search = [437, 3538, 6079, 6094, 6503, 10022, 11356, 11558, 13475, 14764, 14858, 19303, 19724]
# search = [19588]
# search = [93]
# search = [3946]
# search = [17768]
# search = [7875]
# search = [3743]
# search = [4581]
# search = [21, 42, 44, 89, 90, 185, 294, 487, 535, 621, 623, 698, 739, 817, 1074, 1096, 1112, 1265, 1313, 1456, 1695, 1861, 1903, 1993, 2386, 2597, 2653, 2691, 3126, 3218, 3448, 3581, 3795, 3836, 3837, 3910, 3951, 4104, 4397, 4453, 4550, 4835, 5063, 5102, 5155, 5188, 5212, 5433, 5482, 5558, 5614, 5826, 6158, 6172, 6227, 6517, 6569, 6730, 6828, 7022, 7029, 7144, 7527, 7911, 8001, 8027, 8195, 8334, 8871, 8880, 8961, 9170, 9176, 9235, 9295, 9364, 9468, 9470, 9605, 9793, 9847, 10076, 10089, 10233, 10314, 10520, 10537, 10550, 10615, 11147, 11422, 11527, 11529, 11721, 11730, 11883, 11936, 11954, 12005, 12137, 12347, 12438, 12570, 12669, 12714, 12792, 13071, 13173, 13326, 13352, 13510, 13511, 13600, 13602, 13629, 13672, 13677, 13831, 13908, 14111, 14138, 14205, 14320, 14538, 14550, 14582, 14688, 14828, 14880, 14916, 15107, 15181, 15182, 15270, 15310, 15606, 15828, 15844, 15868, 15927, 16238, 16421, 16470, 16707, 16800, 16834, 16866, 16875, 16919, 17041, 17044, 17156, 17192, 17244, 17282, 17437, 17493, 17508, 17605, 17613, 17722, 17741, 17797, 18227, 18303, 18375, 18416, 18529, 18550, 18788, 18863, 19199, 19247, 19339, 19367, 19450, 19521, 19522, 19544, 19608, 19660, 19683, 19825, 19873, 19887, 19963]

# %%
q = findfirst( x -> occursin("TFRC", x), final_sup_two)
# Out:
# 20025
